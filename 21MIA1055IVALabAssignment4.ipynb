# %%
import cv2
import numpy as np
import os
from google.colab.patches import cv2_imshow

def load_video(video_path, resize_dim=(320, 240)):
    cap = cv2.VideoCapture(video_path)
    frames = []

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Resize frame for faster processing
        resized_frame = cv2.resize(frame, resize_dim)
        frames.append(resized_frame)

    cap.release()
    return frames

def convert_to_hsv(frame):
    return cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

def noise_detection(frame):
    blurred = cv2.GaussianBlur(frame, (5, 5), 0)
    noise_mask = cv2.absdiff(frame, blurred)
    return noise_mask

def histogram_comparison(frame1, frame2):
    hist1 = cv2.calcHist([frame1], [0, 1], None, [256, 256], [0, 256, 0, 256])
    hist2 = cv2.calcHist([frame2], [0, 1], None, [256, 256], [0, 256, 0, 256])
    cv2.normalize(hist1, hist1, 0, 1, cv2.NORM_MINMAX)
    cv2.normalize(hist2, hist2, 0, 1, cv2.NORM_MINMAX)


    similarity_score = cv2.compareHist(hist1, hist2, cv2.HISTCMP_CORREL)
    return similarity_score

def sobel_edge_detection(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale before Sobel
    sobel_x = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=5)
    sobel_y = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=5)
    edges = cv2.magnitude(sobel_x, sobel_y)
    return np.uint8(edges)

def find_least_similarity_cuts(similarity_scores, frames, top_n=5):
    # Get the indices of the least similarity scores (lowest values indicate scene cuts)
    least_similar_indices = np.argsort(similarity_scores)[:top_n]

    print(f"Top {top_n} scene cut frames (by least similarity):")
    for i, idx in enumerate(least_similar_indices):
        print(f"Scene cut {i+1}: between frame {idx} and frame {idx+1} with similarity score: {similarity_scores[idx]}")

        # Display the two consecutive frames where the scene cut occurs
        cv2_imshow(frames[idx])
        cv2_imshow(frames[idx+1])
        cv2.waitKey(1000)  # Wait for a key press to display next set of frames

    return least_similar_indices

def process_video(video_path, hsv_directory, noise_directory, edge_directory, top_n_cuts=5, resize_dim=(320, 240)):
    if not os.path.exists(hsv_directory):
        os.makedirs(hsv_directory)
    if not os.path.exists(noise_directory):
         os.makedirs(noise_directory)
    if not os.path.exists(edge_directory):
         os.makedirs(edge_directory)

    frames = load_video(video_path, resize_dim=resize_dim)
    hsv_frames = []
    noise_frames = []
    edge_frames = []
    similarity_scores = []

    for idx, frame in enumerate(frames):
        # Step 2: Convert each frame into HSV
        hsv_frame = convert_to_hsv(frame)
        hsv_frames.append(hsv_frame)
        cv2.imwrite(os.path.join(hsv_directory, f'hsv_frame_{idx}.png'), hsv_frame)

        # Step 3: Detect noise
        noise_frame = noise_detection(frame)
        noise_frames.append(noise_frame)
        cv2.imwrite(os.path.join(noise_directory, f'noise_frame_{idx}.png'), noise_frame)

        # Step 4: Perform histogram comparison with the previous frame
        if idx > 0:
            similarity = histogram_comparison(frames[idx-1], frames[idx])
            similarity_scores.append(similarity)
            print(f'Similarity between frame {idx-1} and frame {idx}: {similarity}')

        # Step 5: Perform edge detection
        edge_frame = sobel_edge_detection(frame)
        edge_frames.append(edge_frame)
        cv2.imwrite(os.path.join(edge_directory, f'edge_frame_{idx}.png'), edge_frame)

    # Step 6: Find least similarity cuts and display the frames
    if len(similarity_scores) > 0:
        least_similar_indices = find_least_similarity_cuts(similarity_scores, frames, top_n_cuts)

        # Optionally, save the frames at the scene cut points for analysis
        for i, idx in enumerate(least_similar_indices):
            cv2.imwrite(os.path.join(hsv_directory, f'scene_cut_frame_{i+1}frame{idx}.png'), frames[idx])
            cv2.imwrite(os.path.join(hsv_directory, f'scene_cut_frame_{i+1}frame{idx+1}.png'), frames[idx+1])


video_path = "/content/Volumeup.mp4"
hsv_directory = "/content/hsv_frames"
noise_directory = "/content/noise_frames"
edge_directory = "/content/edge_frames"
process_video(video_path, hsv_directory, noise_directory, edge_directory, top_n_cuts=10, resize_dim=(320, 240))
# Out:
# Similarity between frame 0 and frame 1: 1.0
# Similarity between frame 1 and frame 2: 1.0
# Similarity between frame 2 and frame 3: 1.0
# Similarity between frame 3 and frame 4: 1.0
# Similarity between frame 4 and frame 5: 1.0
# Similarity between frame 5 and frame 6: 1.0
# Similarity between frame 6 and frame 7: 1.0
# Similarity between frame 7 and frame 8: 1.0
# Similarity between frame 8 and frame 9: 1.0
# Similarity between frame 9 and frame 10: 1.0
# Similarity between frame 10 and frame 11: 1.0
# Similarity between frame 11 and frame 12: 1.0
# Similarity between frame 12 and frame 13: 1.0
# Similarity between frame 13 and frame 14: 0.9999999996608981
# Similarity between frame 14 and frame 15: 0.9999998556975533
# Similarity between frame 15 and frame 16: 0.9999998618687835
# Similarity between frame 16 and frame 17: 0.9999998912501827
# Similarity between frame 17 and frame 18: 0.9999999954847337
# Similarity between frame 18 and frame 19: 0.999999946839358
# Similarity between frame 19 and frame 20: 0.9999999522917317
# Similarity between frame 20 and frame 21: 0.9999999496519424
# Similarity between frame 21 and frame 22: 0.9999999601326376
# Similarity between frame 22 and frame 23: 0.9999999567240369
# Similarity between frame 23 and frame 24: 0.9999999568075496
# Similarity between frame 24 and frame 25: 0.9999999583399877
# Similarity between frame 25 and frame 26: 0.9999999599580862
# Similarity between frame 26 and frame 27: 0.99999997298482
# Similarity between frame 27 and frame 28: 0.9999998882698021
# Similarity between frame 28 and frame 29: 0.9999999817533954
# Similarity between frame 29 and frame 30: 0.9999999570936074
# Similarity between frame 30 and frame 31: 0.999999965619074
# Similarity between frame 31 and frame 32: 0.9999999356825177
# Similarity between frame 32 and frame 33: 0.9999999947162221
# Similarity between frame 33 and frame 34: 0.9999999552179474
# Similarity between frame 34 and frame 35: 0.9999987179861733
# Similarity between frame 35 and frame 36: 0.9999997858311817
# Similarity between frame 36 and frame 37: 0.9999997427308294
# Similarity between frame 37 and frame 38: 0.9999999316232877
# Similarity between frame 38 and frame 39: 0.9999999731244681
# Similarity between frame 39 and frame 40: 0.999999726168706
# Similarity between frame 40 and frame 41: 0.9999999786368772
# Similarity between frame 41 and frame 42: 0.9999997943059937
# Similarity between frame 42 and frame 43: 0.999999977473154
# Similarity between frame 43 and frame 44: 0.9999997100292021
# Similarity between frame 44 and frame 45: 0.9999999744186272
# Similarity between frame 45 and frame 46: 0.9999996835965934
# Similarity between frame 46 and frame 47: 0.9999999265308747
# Similarity between frame 47 and frame 48: 0.9999999165652168
# Similarity between frame 48 and frame 49: 0.9999999557736668
# Similarity between frame 49 and frame 50: 0.9999999573356921
# Similarity between frame 50 and frame 51: 0.999999999653837
# Similarity between frame 51 and frame 52: 0.9999999996538371
# Similarity between frame 52 and frame 53: 0.999999999653837
# Similarity between frame 53 and frame 54: 0.9999999947182924
# Similarity between frame 54 and frame 55: 0.9999998539287187
# Similarity between frame 55 and frame 56: 0.999999995320817
# Similarity between frame 56 and frame 57: 0.9999999996535455
# Similarity between frame 57 and frame 58: 0.9999999987874083
# Similarity between frame 58 and frame 59: 0.9999999994803177
# Similarity between frame 59 and frame 60: 0.9999999859692542
# Similarity between frame 60 and frame 61: 0.9999999661481703
# Similarity between frame 61 and frame 62: 0.9999999823364104
# Similarity between frame 62 and frame 63: 0.9999999866663992
# Similarity between frame 63 and frame 64: 0.9999999632031776
# Similarity between frame 64 and frame 65: 0.9999999826840945
# Similarity between frame 65 and frame 66: 1.0
# Similarity between frame 66 and frame 67: 1.0
# Similarity between frame 67 and frame 68: 1.0
# Similarity between frame 68 and frame 69: 0.9999999968810669
# Similarity between frame 69 and frame 70: 0.9999999973154745
# Similarity between frame 70 and frame 71: 0.9999998649427301
# Similarity between frame 71 and frame 72: 0.9999999994806457
# Similarity between frame 72 and frame 73: 0.9999999988743317
# Similarity between frame 73 and frame 74: 0.9999999996537726
# Similarity between frame 74 and frame 75: 0.9999999996537728
# Similarity between frame 75 and frame 76: 0.9999999988709564
# Similarity between frame 76 and frame 77: 0.9999999996537456
# Similarity between frame 77 and frame 78: 0.9999999975762189
# Similarity between frame 78 and frame 79: 0.9999999930670868
# Similarity between frame 79 and frame 80: 0.9999999960184918
# Similarity between frame 80 and frame 81: 1.0
# Similarity between frame 81 and frame 82: 1.0
# Similarity between frame 82 and frame 83: 1.0
# Similarity between frame 83 and frame 84: 1.0
# Similarity between frame 84 and frame 85: 1.0
# Similarity between frame 85 and frame 86: 1.0
# Similarity between frame 86 and frame 87: 0.9999999368152056
# Similarity between frame 87 and frame 88: 0.9999999421815834
# Similarity between frame 88 and frame 89: 0.999999925649086
# Similarity between frame 89 and frame 90: 0.9999998907768177
# Similarity between frame 90 and frame 91: 0.9999988673936803
# Similarity between frame 91 and frame 92: 0.9999999023076049
# Similarity between frame 92 and frame 93: 0.999999880803311
# Similarity between frame 93 and frame 94: 0.9999996721951033
# Similarity between frame 94 and frame 95: 0.9999996823664219
# Similarity between frame 95 and frame 96: 0.9999996725604716
# Similarity between frame 96 and frame 97: 0.9999990921210077
# Similarity between frame 97 and frame 98: 1.0
# Similarity between frame 98 and frame 99: 1.0
# Similarity between frame 99 and frame 100: 1.0
# Similarity between frame 100 and frame 101: 1.0
# Similarity between frame 101 and frame 102: 1.0
# Similarity between frame 102 and frame 103: 1.0
# Similarity between frame 103 and frame 104: 1.0
# Similarity between frame 104 and frame 105: 1.0
# Similarity between frame 105 and frame 106: 1.0
# Similarity between frame 106 and frame 107: 1.0
# Similarity between frame 107 and frame 108: 1.0
# Similarity between frame 108 and frame 109: 1.0
# Similarity between frame 109 and frame 110: 1.0
# Similarity between frame 110 and frame 111: 1.0
# Similarity between frame 111 and frame 112: 1.0
# Similarity between frame 112 and frame 113: 1.0
# Similarity between frame 113 and frame 114: 1.0
# Similarity between frame 114 and frame 115: 1.0
# Similarity between frame 115 and frame 116: 1.0
# Similarity between frame 116 and frame 117: 1.0
# Similarity between frame 117 and frame 118: 1.0
# Similarity between frame 118 and frame 119: 1.0
# Similarity between frame 119 and frame 120: 1.0
# Similarity between frame 120 and frame 121: 1.0
# Similarity between frame 121 and frame 122: 1.0
# Similarity between frame 122 and frame 123: 1.0
# Similarity between frame 123 and frame 124: 1.0
# Similarity between frame 124 and frame 125: 1.0
# Similarity between frame 125 and frame 126: 1.0
# Similarity between frame 126 and frame 127: 1.0
# Similarity between frame 127 and frame 128: 1.0
# Similarity between frame 128 and frame 129: 1.0
# Similarity between frame 129 and frame 130: 1.0
# Similarity between frame 130 and frame 131: 1.0
# Similarity between frame 131 and frame 132: 1.0
# Similarity between frame 132 and frame 133: 1.0
# Similarity between frame 133 and frame 134: 1.0
# Similarity between frame 134 and frame 135: 1.0
# Similarity between frame 135 and frame 136: 1.0
# Similarity between frame 136 and frame 137: 1.0
# Similarity between frame 137 and frame 138: 1.0
# Similarity between frame 138 and frame 139: 1.0
# Similarity between frame 139 and frame 140: 1.0
# Similarity between frame 140 and frame 141: 1.0
# Similarity between frame 141 and frame 142: 1.0
# Similarity between frame 142 and frame 143: 1.0
# Similarity between frame 143 and frame 144: 1.0
# Similarity between frame 144 and frame 145: 1.0
# Similarity between frame 145 and frame 146: 1.0
# Similarity between frame 146 and frame 147: 1.0
# Similarity between frame 147 and frame 148: 1.0
# Similarity between frame 148 and frame 149: 1.0
# Similarity between frame 149 and frame 150: 1.0
# Similarity between frame 150 and frame 151: 1.0
# Similarity between frame 151 and frame 152: 1.0
# Similarity between frame 152 and frame 153: 1.0
# Similarity between frame 153 and frame 154: 1.0
# Similarity between frame 154 and frame 155: 1.0
# Similarity between frame 155 and frame 156: 1.0
# Similarity between frame 156 and frame 157: 1.0
# Similarity between frame 157 and frame 158: 1.0
# Similarity between frame 158 and frame 159: 1.0
# Similarity between frame 159 and frame 160: 1.0
# Similarity between frame 160 and frame 161: 1.0
# Similarity between frame 161 and frame 162: 1.0
# Similarity between frame 162 and frame 163: 1.0
# Similarity between frame 163 and frame 164: 1.0
# Similarity between frame 164 and frame 165: 1.0
# Similarity between frame 165 and frame 166: 1.0
# Similarity between frame 166 and frame 167: 0.9820250244492189
# Similarity between frame 167 and frame 168: 0.99811992052905
# Similarity between frame 168 and frame 169: 0.9963434238280042
# Similarity between frame 169 and frame 170: 0.99435671137148
# Similarity between frame 170 and frame 171: 0.9934113987935209
# Similarity between frame 171 and frame 172: 0.9969839564919585
# Similarity between frame 172 and frame 173: 0.9954712413177751
# Similarity between frame 173 and frame 174: 0.995537193854656
# Similarity between frame 174 and frame 175: 0.993906393292177
# Similarity between frame 175 and frame 176: 0.9989595789043909
# Similarity between frame 176 and frame 177: 0.9987843510496289
# Similarity between frame 177 and frame 178: 0.999636720391037
# Similarity between frame 178 and frame 179: 0.9992410858680116
# Similarity between frame 179 and frame 180: 0.9995375227324808
# Similarity between frame 180 and frame 181: 0.999678512428241
# Similarity between frame 181 and frame 182: 0.9997564798811779
# Similarity between frame 182 and frame 183: 0.9996793263608695
# Similarity between frame 183 and frame 184: 0.9998666437632685
# Similarity between frame 184 and frame 185: 0.9870999782196243
# Similarity between frame 185 and frame 186: 0.8919822058625893
# Similarity between frame 186 and frame 187: 0.8795674466738308
# Similarity between frame 187 and frame 188: 0.996704015995712
# Similarity between frame 188 and frame 189: 0.9759568621584441
# Similarity between frame 189 and frame 190: 0.9592120652364609
# Similarity between frame 190 and frame 191: 0.9651445045619923
# Similarity between frame 191 and frame 192: 0.9648550737024205
# Similarity between frame 192 and frame 193: 0.988626912024544
# Similarity between frame 193 and frame 194: 0.97643134194661
# Similarity between frame 194 and frame 195: 0.965814480634062
# Similarity between frame 195 and frame 196: 0.9782674856476018
# Similarity between frame 196 and frame 197: 0.9846271098943796
# Similarity between frame 197 and frame 198: 0.9989294071288796
# Similarity between frame 198 and frame 199: 0.9987779387186975
# Similarity between frame 199 and frame 200: 0.9994563490639872
# Similarity between frame 200 and frame 201: 0.9997263144568607
# Similarity between frame 201 and frame 202: 0.9998438323513056
# Similarity between frame 202 and frame 203: 0.9994522734831268
# Similarity between frame 203 and frame 204: 0.9997553041157378
# Similarity between frame 204 and frame 205: 0.9759617702469875
# Similarity between frame 205 and frame 206: 0.40837782451194704
# Similarity between frame 206 and frame 207: 0.26900341300586
# Similarity between frame 207 and frame 208: 0.8018028046500926
# Similarity between frame 208 and frame 209: 0.9505381980570624
# Similarity between frame 209 and frame 210: 0.882953724871169
# Similarity between frame 210 and frame 211: 0.930039076486853
# Similarity between frame 211 and frame 212: 0.8940374839660407
# Similarity between frame 212 and frame 213: 0.9321511431379267
# Similarity between frame 213 and frame 214: 0.9098374113827795
# Similarity between frame 214 and frame 215: 0.8566873779984456
# Similarity between frame 215 and frame 216: 0.9331940049108486
# Similarity between frame 216 and frame 217: 0.9704190233807157
# Similarity between frame 217 and frame 218: 0.9909574323259657
# Similarity between frame 218 and frame 219: 0.9950577843070315
# Similarity between frame 219 and frame 220: 0.9958943178961142
# Similarity between frame 220 and frame 221: 0.9969928988636474
# Similarity between frame 221 and frame 222: 0.9973552100831811
# Similarity between frame 222 and frame 223: 0.9959393730625856
# Similarity between frame 223 and frame 224: 0.995648540738518
# Similarity between frame 224 and frame 225: 0.9974530985380521
# Similarity between frame 225 and frame 226: 0.8497409856679625
# Similarity between frame 226 and frame 227: 0.7282863617541586
# Similarity between frame 227 and frame 228: 0.28324908903137175
# Similarity between frame 228 and frame 229: 0.9941334939317699
# Similarity between frame 229 and frame 230: 0.8624369087198649
# Similarity between frame 230 and frame 231: 0.9222587328802784
# Similarity between frame 231 and frame 232: 0.9575234925167887
# Similarity between frame 232 and frame 233: 0.8133323584602886
# Similarity between frame 233 and frame 234: 0.8103498676324555
# Similarity between frame 234 and frame 235: 0.7849252088406521
# Similarity between frame 235 and frame 236: 0.8131021848465313
# Similarity between frame 236 and frame 237: 0.9334671724578312
# Similarity between frame 237 and frame 238: 0.9858894367811532
# Similarity between frame 238 and frame 239: 0.9993449890916885
# Similarity between frame 239 and frame 240: 0.998440517841108
# Similarity between frame 240 and frame 241: 0.9990246104393822
# Similarity between frame 241 and frame 242: 0.9982271276112462
# Similarity between frame 242 and frame 243: 0.9980029899234324
# Similarity between frame 243 and frame 244: 0.9981800066090616
# Similarity between frame 244 and frame 245: 0.9878976056776397
# Similarity between frame 245 and frame 246: 0.9975610263895552
# Similarity between frame 246 and frame 247: 0.8065175037890912
# Similarity between frame 247 and frame 248: 0.6222813812051063
# Similarity between frame 248 and frame 249: 0.373224257520027
# Similarity between frame 249 and frame 250: 0.9778575892276127
# Similarity between frame 250 and frame 251: 0.9820736372164961
# Similarity between frame 251 and frame 252: 0.9778814814604277
# Similarity between frame 252 and frame 253: 0.9816598487271492
# Similarity between frame 253 and frame 254: 0.9794088530225845
# Similarity between frame 254 and frame 255: 0.9845300390308646
# Similarity between frame 255 and frame 256: 0.9913643102139943
# Similarity between frame 256 and frame 257: 0.980730982579857
# Similarity between frame 257 and frame 258: 0.9913780775694299
# Similarity between frame 258 and frame 259: 0.9992731818969639
# Similarity between frame 259 and frame 260: 0.998914539848495
# Similarity between frame 260 and frame 261: 0.9995340377759258
# Similarity between frame 261 and frame 262: 0.9993020150693575
# Similarity between frame 262 and frame 263: 0.9995636310744475
# Similarity between frame 263 and frame 264: 0.9988209274901859
# Similarity between frame 264 and frame 265: 0.9988712795178567
# Similarity between frame 265 and frame 266: 0.9994245108819143
# Similarity between frame 266 and frame 267: 0.9995852699491451
# Similarity between frame 267 and frame 268: 0.934842662891303
# Similarity between frame 268 and frame 269: 0.9130013619947399
# Similarity between frame 269 and frame 270: 0.89940910065529
# Similarity between frame 270 and frame 271: 0.9991922141699714
# Similarity between frame 271 and frame 272: 0.9985746411816412
# Similarity between frame 272 and frame 273: 0.9989309863213887
# Similarity between frame 273 and frame 274: 0.9977275693726132
# Similarity between frame 274 and frame 275: 0.998600248860503
# Similarity between frame 275 and frame 276: 0.9976898622733067
# Similarity between frame 276 and frame 277: 0.9948832548409531
# Similarity between frame 277 and frame 278: 0.9976950410451444
# Similarity between frame 278 and frame 279: 0.9943677647110405
# Similarity between frame 279 and frame 280: 0.9996976230816348
# Similarity between frame 280 and frame 281: 0.9998809575160269
# Similarity between frame 281 and frame 282: 0.9998059122813829
# Similarity between frame 282 and frame 283: 0.9998691349397375
# Similarity between frame 283 and frame 284: 0.9998623564379895
# Similarity between frame 284 and frame 285: 0.9999054269582874
# Similarity between frame 285 and frame 286: 0.9998995276485247
# Similarity between frame 286 and frame 287: 0.9998697982049511
# Similarity between frame 287 and frame 288: 0.9998961753778626
# Similarity between frame 288 and frame 289: 0.9828535924533888
# Similarity between frame 289 and frame 290: 0.9666859194894526
# Similarity between frame 290 and frame 291: 0.923088964946553
# Similarity between frame 291 and frame 292: 0.947106996896577
# Similarity between frame 292 and frame 293: 0.6390327677749291
# Similarity between frame 293 and frame 294: 0.6605338753939304
# Similarity between frame 294 and frame 295: 0.9222593667861725
# Similarity between frame 295 and frame 296: 0.9258390735047
# Similarity between frame 296 and frame 297: 0.9317901712905277
# Similarity between frame 297 and frame 298: 0.9241697977936947
# Similarity between frame 298 and frame 299: 0.9422388222099517
# Similarity between frame 299 and frame 300: 0.9253689957022808
# Similarity between frame 300 and frame 301: 0.997784940069926
# Similarity between frame 301 and frame 302: 0.9986873618620183
# Similarity between frame 302 and frame 303: 0.9992274117650845
# Similarity between frame 303 and frame 304: 0.9989352351137324
# Similarity between frame 304 and frame 305: 0.9977666314201945
# Similarity between frame 305 and frame 306: 0.9995412534927823
# Similarity between frame 306 and frame 307: 0.9993407430177607
# Similarity between frame 307 and frame 308: 0.9985298419151906
# Similarity between frame 308 and frame 309: 0.9992379826605157
# Similarity between frame 309 and frame 310: 0.8959910911125089
# Similarity between frame 310 and frame 311: 0.7154586763454502
# Similarity between frame 311 and frame 312: 0.2643489399696872
# Similarity between frame 312 and frame 313: 0.4031800220659091
# Similarity between frame 313 and frame 314: 0.4004167680851184
# Similarity between frame 314 and frame 315: 0.43837930357840815
# Similarity between frame 315 and frame 316: 0.5448168405991514
# Similarity between frame 316 and frame 317: 0.527072832428482
# Similarity between frame 317 and frame 318: 0.5737397010821441
# Similarity between frame 318 and frame 319: 0.6214393239961069
# Similarity between frame 319 and frame 320: 0.6985404981736327
# Similarity between frame 320 and frame 321: 0.7713565965777435
# Similarity between frame 321 and frame 322: 0.8950596255353819
# Similarity between frame 322 and frame 323: 0.7867736040723343
# Similarity between frame 323 and frame 324: 0.676068598808872
# Similarity between frame 324 and frame 325: 0.7799613803839517
# Similarity between frame 325 and frame 326: 0.752144022034688
# Similarity between frame 326 and frame 327: 0.6645476054418916
# Similarity between frame 327 and frame 328: 0.8059135658172842
# Similarity between frame 328 and frame 329: 0.7830855967335405
# Similarity between frame 329 and frame 330: 0.5970577772941761
# Similarity between frame 330 and frame 331: 0.6879865479274871
# Similarity between frame 331 and frame 332: 0.7799608128114954
# Similarity between frame 332 and frame 333: 0.5581576256669325
# Top 10 scene cut frames (by least similarity):
# Scene cut 1: between frame 311 and frame 312 with similarity score: 0.2643489399696872
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 2: between frame 206 and frame 207 with similarity score: 0.26900341300586
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 3: between frame 227 and frame 228 with similarity score: 0.28324908903137175
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 4: between frame 248 and frame 249 with similarity score: 0.373224257520027
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 5: between frame 313 and frame 314 with similarity score: 0.4004167680851184
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 6: between frame 312 and frame 313 with similarity score: 0.4031800220659091
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 7: between frame 205 and frame 206 with similarity score: 0.40837782451194704
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 8: between frame 314 and frame 315 with similarity score: 0.43837930357840815
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 9: between frame 316 and frame 317 with similarity score: 0.527072832428482
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 10: between frame 315 and frame 316 with similarity score: 0.5448168405991514
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>

# %%
import shutil
from google.colab import files

def download_directory(directory_path, zip_filename):
  shutil.make_archive(zip_filename, 'zip', directory_path)
  files.download(zip_filename + '.zip')


download_directory(hsv_directory, 'hsv_frames')
download_directory(noise_directory, 'noise_frames')
download_directory(edge_directory, 'edge_frames')
